# %%
# Load your dataset
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
pip install ydata-profiling
# Out:
# ...
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/678.1 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/678.1 kB ? eta -:--:--
#    ----------------------------- -------- 524.3/678.1 kB 586.1 kB/s eta 0:00:01
#    -------------------------------------- 678.1/678.1 kB 615.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
# ...

# %%
#using ydta_profiling because pandas_profiling no longer support
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Real Estate EDA")
profile.to_notebook_iframe()  # displays inside Jupyter"
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/23 [00:00<?, ?it/s]
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.18.4&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-06-12 05:16:00.643065&quot; name=date&gt;&lt;title&gt;Real Estate EDA&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
# ...
