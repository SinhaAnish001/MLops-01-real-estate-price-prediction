# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None )

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                 society             sector  price  \
# 0          flat             zara aavaas         sector 104   0.20
# 1          flat  landmark the residency         sector 103   0.90
# 2          flat         ramprastha city  dwarka expressway   1.30
# 3          flat              ireo skyon          sector 60   3.80
# 4          flat    breez global heights          sector 36   0.24
#
#    price_per_sqft    area                                       areaWithType  \
# 0          6644.0   301.0                     Carpet area: 301 (27.96 sq.m.)
# 1          6666.0  1350.0             Super Built up area 1350(125.42 sq.m.)
# 2          9027.0  1440.0             Super Built up area 1440(133.78 sq.m.)
# 3         13571.0  2800.0  Super Built up area 2800(260.13 sq.m.)Built Up...
# 4          5825.0   412.0                     Carpet area: 412 (38.28 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.shape
# Out:
# (3718, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.displot(df['price'])

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 2452         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2127         house                                        independent
# 2039         house                                        independent
# 1818         house                                     dlf city plots
# 2167         house                                   suncity township
# 224          house                             emaar the palm springs
# 1786         house                                        independent
# 3048         house                                 vipul tatvam villa
# 2945         house                                        independent
# 3032         house                                     dlf city plots
# 3682         house                             luxury dlf city floors
# 1924         house                                        independent
# ...

# %% [markdown]
# #### on the basis of price col we can say that most of the outliers are genuine but there are some data errors as well

# %%
# moving to the next column price_per_sqft
sns.displot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# calculate IQR 
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

#define boundaries
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52734.477401
#  std       61126.792100
#  min       24557.000000
#  25%       28270.250000
#  50%       33498.000000
#  75%       42048.500000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
# here the mean is too high and when we look to the original data we found that some of the area is written in yards and some in sqft 
# and using area and price we calculated price_per_sqft 
# so we changed the area of outliers only where it is <1000 from yards to sqft by multiplying it with 9
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

#then recalculated the price_per_sqft of those outliers
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\256186522.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\256186522.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      350.000000
# mean     29475.674286
# std      12383.445811
# min       2778.000000
# 25%      25880.250000
# 50%      29880.000000
# 75%      35694.750000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
# now mean dropped down a little so we updated the original data
df.update(outliers_sqft)

# %%
sns.displot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# plot the values >50000
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 224          house        emaar the palm springs        sector 54  24.00
# 513          house                   independent        sector 25  16.00
# 1496         house                unitech escape        sector 50  10.80
# 1543         house                   independent        sector 13    NaN
# 1547         house            emaar mgf marbella        sector 66  18.00
# 1644          flat                unitech vistas        sector 70   9.00
# 1801         house                           nul        sector 28  12.50
# 1818         house                dlf city plots        sector 26  26.00
# 1931         house                   independent        sector 26  14.75
# 2039         house                   independent        sector 26  26.00
# 2332         house  project housing board colony        sector 31   8.00
# 3178         house            cloudnine cottages  sohna road road   5.50
# ...

# %%
df[df['price_per_sqft']>50000].shape
# Out:
# (14, 23)

# %%
# there are 14 values so i removed them
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# # area

# %%
df[['area']]
# Out:
#         area
# 0      301.0
# 1     1350.0
# 2     1440.0
# 3     2800.0
# 4      412.0
# ...      ...
# 3847  1210.0
# 3848  2295.0
# 3849     NaN
# 3850   450.0
# 3851   500.0
#
# [3679 rows x 1 columns]

# %%
sns.histplot(df['area'])
plt.xlim(0, 12000)
plt.show()

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2945.709899
# std       23208.051480
# min         145.000000
# 25%        1261.500000
# 50%        1750.000000
# 75%        2347.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 1020          flat      signature the roselia   sector 95   0.45
# 1589          flat            ramsons kshitij   sector 95   0.31
# 1922          flat          hcbs sports ville  sohna road   0.35
# 2042         house                independent   sector 50   5.00
# 3120          flat  signature global solera 2  sector 107   0.51
#
#       price_per_sqft      area                           areaWithType  \
# 1020             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1589             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 1922             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 2042           232.0  215517.0             Plot area 2(1011.71 sq.m.)
# 3120             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1020      2.0       2.0       2       2.0  South-West    New Property
# ...

# %%
df[df['area'] > 100000].shape
# Out:
# (5, 23)

# %%
df = df[df['area'] < 100000]

# %%
sns.displot(df['area'])
plt.xlim(0,12000)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 2397         house                independent        sector 26  18.40
# 1970         house  ganpati heights apartment        sector 13   1.25
# 1380          flat                 rof ananda        sector 95   0.38
# 3764          flat                 rof ananda        sector 95   0.38
# 1054         house      dlf city plot phase 4        sector 28  13.00
# 3339          flat              pyramid elite        sector 86   0.46
# 2741          flat                 rof ananda        sector 95   0.33
# 42            flat      signature the serenas       sohna road   0.28
# 990          house                independent        sector 25   7.30
# 373           flat            ramsons kshitij        sector 95   0.24
# 2458          flat                 rof ananda        sector 95   0.21
# 2268         house                independent        sector 57   6.25
# ...

# %%
df.drop(index=[2397, 1380, 3764, 3339, 2741, 42, 373, 2458, 2599], inplace=True)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\2682269969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=[2397, 1380, 3764, 3339, 2741, 42, 373, 2458, 2599], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 1970         house  ganpati heights apartment        sector 13   1.25
# 1054         house      dlf city plot phase 4        sector 28  13.00
# 990          house                independent        sector 25   7.30
# 2268         house                independent        sector 57   6.25
# 3221         house                independent        sector 43   5.50
# 1357          flat                 godrej air        sector 85   2.50
# 1852         house       unitech aspen greens        sector 50   6.95
# 2041          flat                godrej icon       sector 88a   1.75
# 2127         house                independent        sector 43  27.50
# 2667          flat             m3m golfestate        sector 65  13.20
# 1181         house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 1970           151.0  82781.0
# 1054          1992.0  65261.0
# 990           1560.0  46795.0
# ...

# %%
df.loc[1970,'area'] = 115*9
df.loc[1054,'area'] = 7250
df.loc[990,'area'] = 5800
df.loc[2268,'area'] = 2660
df.loc[3321,'area'] = 2850
df.loc[1357,'area'] = 1812
df.loc[1852,'area'] = 2160
df.loc[2041,'area'] = 1175

# %%
sns.displot(df['area'],stat='density')

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 17500]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 3221         house  independent  sector 43    5.5          2716.0  20250.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3221  Plot area 215(179.77 sq.m.)Built Up area: 2850...      8.0       7.0
#
#      balcony  floorNum facing   agePossession  super_built_up_area  \
# 3221      3+       3.0   East  Moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 3221         2850.0       2250.0           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 3221           1       1                2           123

# %%
df.loc[3221, 'area'] = 2850
# recalculating price_per_sqft
df.loc[3221, 'price_per_sqft'] = df.loc[3221, 'price'] / df.loc[3221, 'area']

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1948.967795
# std       1211.178820
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ## Bedroom

# %%
sns.displot(df['bedRoom'])

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 961          house                  independent   sector 54   5.00
# 2690         house                  independent   sector 43   4.50
# 1116         house                  independent  sector 17a   3.87
# 2266         house                  independent  sector 17a   3.93
# 38           house                private house   sector 55   7.05
# 3327         house                  independent   sector 54   5.50
# 3039         house                  independent   sector 11   4.50
# 3403         house                  independent   sector 40  12.00
# 2638         house                  independent   sector 55   9.19
# 1493         house                  independent   sector 56  12.39
# 115          house                  independent   sector 43  13.50
# 3682         house       luxury dlf city floors   sector 26  20.00
# 3032         house               dlf city plots   sector 26  20.00
# ...

# %%
df[df['bedRoom'] > 10].shape
# Out:
# (45, 23)

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.displot(df['bedRoom'])

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ## Bathroom

# %%
sns.displot(df['bathroom'])

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 921          house  adani brahma samsara  sector 60  18.02         28200.0
# 29           house           independent  sector 24  11.00         28902.0
# 3507         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 921   6390.0                 Built Up area: 6390 (593.65 sq.m.)      9.0
# 29    3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...      8.0
# 3507  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...     10.0
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 921       12.0      3+       3.0  North-East  Relatively New
# 29        11.0      3+       3.0        East    Old Property
# 3507      11.0      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %% [markdown]
# ## super built up area

# %%
sns.displot(df['super_built_up_area'])

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 158           flat  bestech park view grand spa    sector 81    4.7
# 1971          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 158           6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 1971          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 158       4.0       4.0      3+      19.0       North  Relatively New
# 1971      5.0       6.0      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 158                6926.0            NaN          NaN           0
# 1971              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ## built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %% [markdown]
# ## carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 1357          flat      godrej air  sector 85    2.5          1379.0   1812.0
# 2667          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 1357  Carpet area: 18122 (1683.59 sq.m.)      4.0       5.0      3+      16.0
# 2667  Carpet area: 11000 (1021.93 sq.m.)      4.0       4.0       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 1357  North-East  Under Construction                  NaN            NaN
# 2667       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 1357      18122.0           1             0           0           1       1
# 2667      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %%
df.loc[1357,'carpet_area'] = 1812

# %%
df.head()
# Out:
#   property_type                 society             sector  price  \
# 0          flat             zara aavaas         sector 104   0.20
# 1          flat  landmark the residency         sector 103   0.90
# 2          flat         ramprastha city  dwarka expressway   1.30
# 3          flat              ireo skyon          sector 60   3.80
# 4          flat    breez global heights          sector 36   0.24
#
#    price_per_sqft    area                                       areaWithType  \
# 0          6644.0   301.0                     Carpet area: 301 (27.96 sq.m.)
# 1          6666.0  1350.0             Super Built up area 1350(125.42 sq.m.)
# 2          9027.0  1440.0             Super Built up area 1440(133.78 sq.m.)
# 3         13571.0  2800.0  Super Built up area 2800(260.13 sq.m.)Built Up...
# 4          5825.0   412.0                     Carpet area: 412 (38.28 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...

# %% [markdown]
# ## luxury_score

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(x=df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score'>

# %%
# as we have changed some area so we must reclculte the price_per_sqft column
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\2166756109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_2080\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 278          house                   independent   sector 26   19.0
# 301          house                   independent  sector 105    9.9
# 1392         house  sushant lok 1 builder floors   sector 43   13.0
# 1889         house                   independent   sector 43    9.5
# 2111         house                   independent   sector 28   12.0
# 2945         house                   independent   sector 26   20.0
# 3041         house                   independent   sector 25   13.0
# 3643         house                   independent   sector 55    5.0
# 3733         house                dlf city plots   sector 26   19.0
#
#       price_per_sqft    area  \
# 278          42222.0  4500.0
# 301          49500.0  2000.0
# 1392         48148.0  2700.0
# 1889         42222.0  2250.0
# 2111         42194.0  2844.0
# 2945         44444.0  4500.0
# 3041         45710.0  2844.0
# 3643         44444.0  1125.0
# ...

# %%
# as we know that price_per_sqft <20000 is my perfect value then we calculated its area vs bedroom ratio of top 2%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# np.float64(183.33333333333334)

# %%
# and now comparing the whole data on the basis of that perfect ratio
df[(df['area']/df['bedRoom'])<183]
# Out:
#      property_type             society            sector  price  \
# 82           house         independent   sohna road road   1.20
# 147          house         independent  sector 3 phase 2   0.85
# 241          house         independent         sector 13   1.50
# 286          house         independent          sector 4   0.50
# 389          house           rk excelo         sector 12   0.60
# ...            ...                 ...               ...    ...
# 3602         house         independent          sector 4   0.50
# 3643         house         independent         sector 55   5.00
# 3686         house  sai kripa floors 5         sector 11   0.90
# 3787         house      not applicable          sector 4   0.51
# 3833         house         independent         sector 12   0.90
#
#       price_per_sqft    area  \
# 82           22305.0   538.0
# 147           9444.0   900.0
# 241          11538.0  1300.0
# 286          10482.0   477.0
# 389          13333.0   450.0
# ...

# %%
# conclusion : there are alot of improper values in these columns as you compare there are and no. of bedrooms 
# for ex : it is not valid for a house of area 800 have 5 bedrooms , 5 bathrooms and 3 balconies 
# these are treated later
